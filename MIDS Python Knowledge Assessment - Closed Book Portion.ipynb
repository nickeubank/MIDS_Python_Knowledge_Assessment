# %% [markdown]
# # MIDS Python Knowledge Assessment
#
# Welcome to the MIDS Knowledge Assessment. The purpose of this assessment is to give MIDS instructors as sense of your current comfort level with Python following our summer courses and in-person BootCamp.
#
# ## This is **not** a test, and this is **not** graded.
#
# You will find questions on this exam that we do not expect you to be able to do based only on what we've taught you over the summer; those questions have been included so we can figure out if there are students who have done lots of Python before MIDS. So do your best, but don't worry if there are questions you can't do!
#
# That also means that if you don't know how to do something, **please don't spend all your time trying to figure it out!**. There *will* be questions you don't know how to do, so when you find one, just move on!

# %% [markdown]
# ## Part 1: Closed Book Questions (10 minutes)
#
# For this portion of the exam, please **DO NOT** use your computers, just write your answers with a pen or pencil.
#
#
# **(1)** Consider the following code:
#
# ```python
# x = 0
# for i in range(5):
#     x = x + i
# print(x)
# ```
#
# What will Python print out at the end of this code?
#
#
# ```
#
#
#
#
#
#
# ```
#
#
#
# **(2)** Consider the following code:
#
# ```python
# x = [1, 2, 3]
# y = x
#
# x.append(4)
# # Note: `.append(4)` will add the number 4 as the last entry
# # in the list associated with x.
#
# print(y)
# ```
#
# What will Python print out at the end of this code?
#
# ```
#
#
#
#
#
#
# ```
#
#
#
#
# **(3)** Consider the following code:
#
# ```python
# x = 'this is a string'
# y = x
# x = x.upper()
# print(y)
# ```
#
# What will Python print out at the end of this code?
#
# ```
#
#
#
#
#
#
# ```
